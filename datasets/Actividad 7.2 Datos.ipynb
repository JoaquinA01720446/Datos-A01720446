# %%
import pandas as pd
path = "antropometria-dataset.csv"
df = pd.read_csv(path)

df.head(3)
# Out:
#     folio  intp  entidad        desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21          PUEBLA     2    38      8  73.70     2
# 1  101655     3       10         DURANGO     2    11     11  35.65     2
# 2   10287     6        1  AGUASCALIENTES     2    18      8  54.80     1
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
#
#   est_urb est_marg       pondef  est_var
# 0       3        1  3470.002176      215
# 1       1        1   417.946672      101
# 2       3        1   472.980811       15
#
# [3 rows x 26 columns]

# %%
hombres = df.loc[df['sexo']==1]
mujeres = df.loc[df['sexo']==2]

peso_mujeres = mujeres['peso']
peso_hombres = hombres['peso']
cintura_mujeres = mujeres['cintura']
cintura_hombres = hombres['cintura']

sistol = df['sistol']
diastol = df['diastol']

peso = df['peso']
cintura = df['cintura']

# %%
plt.figure(figsize=(8,3))

plt.subplot(1,2,1)
plt.hist(x = sistol, bins = 10)
plt.title("Sistol")

plt.subplot(1,2,2)
plt.hist(x = diastol, bins = 10)
plt.title("Diastol")

plt.show()

# %%
plt.figure(figsize=(8,3))

plt.subplot(1,2,1)
plt.hist(x = peso, bins = 10)
plt.title("Peso")

plt.subplot(1,2,2)
plt.hist(x = cintura, bins = 10)
plt.title("Cintura")

plt.show()

# %%
plt.figure(figsize=(4,4))
plt.scatter(x = peso, y = cintura)
plt.xlabel("'Peso'")
plt.ylabel("'Cintura'")
plt.title("Peso vs Cintura")

plt.show()

# %%
peso_mujeres = mujeres['peso']
cintura_mujeres = mujeres['cintura']

plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
plt.hist(x = peso_mujeres, bins = 10)
plt.title("Distribución peso mujeres")

plt.subplot(1,2,2)
plt.hist(x = cintura_mujeres, bins = 10)
plt.title("Distribución cintura mujeres")

plt.show()

peso_hombres = hombres['peso']
cintura_hombres = hombres['cintura']

plt.figure(figsize=(9,4))
plt.subplot(1,2,1)
plt.hist(x = peso_hombres, bins = 10)
plt.title("Distribución peso hombres")

plt.subplot(1,2,2)
plt.hist(x = cintura_hombres, bins = 10)
plt.title("Distribución cintura hombres")

plt.show()

# %%
plt.figure(figsize=(4,4))
plt.scatter(x = peso_mujeres, y = cintura_mujeres)
plt.xlabel("'Peso'")
plt.ylabel("'Cintura'")
plt.title("Peso mujeres vs cintura mujeres")
plt.show()

plt.figure(figsize=(4,4))
plt.scatter(x = peso_hombres, y = cintura_hombres)
plt.xlabel("'Peso'")
plt.ylabel("'Cintura'")
plt.title("Peso hombres vs cintura hombres")
# Out:
# Text(0.5, 1.0, 'Peso hombres vs cintura hombres')
