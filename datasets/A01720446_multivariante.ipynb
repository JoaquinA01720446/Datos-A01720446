# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datasets/antropometria-dataset.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
men = df.loc[df['sexo']==1]
fem = df.loc[df['sexo']==2]

menweight = men['peso']
femweight = fem['peso']

menwaist = men['cintura']
femwaist = fem['cintura']

sistol = df['sistol']
diastol = df['diastol']

weight = df['peso']
waist = df['cintura']

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.hist(x = sistol, bins = 10)
plt.title('Histograma Sistol')

plt.subplot(1,2,2)
plt.hist(x = diastol, bins = 10)
plt.title('Histograma Diastol')

plt.show()

# %%
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.hist(x = weight, bins = 10)
plt.title("Histograma Peso")

plt.subplot(1,2,2)
plt.hist(x = waist, bins = 10)
plt.title("Histograma Cintura")

plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.figure(figsize=(6,6))
plt.scatter(x = waist, y = weight)
plt.xlabel("'Cintura'")
plt.ylabel("'Peso'")
plt.title("Cintura x Peso")

plt.show()

# %%
femweight = fem['peso']
femwaist = fem['cintura']

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.hist(x = femweight, bins = 10)
plt.title('Peso de las Mujeres')
plt.subplot(1,2,2)
plt.hist(x = femwaist, bins = 10)
plt.title('Cintura de las Mujeres')

plt.show()


menweight = men['peso']
menwaist = men['cintura']

plt.figure(figsize = (10,4))
plt.subplot(1,2,1)
plt.hist(x = menweight, bins = 10)
plt.title('Peso de los Hombres')
plt.subplot(1,2,2)
plt.hist(x = menwaist, bins = 10)
plt.title('Cintura de los Hombres')

plt.show()

# %%
plt.figure(figsize = (6,6))
plt.scatter(x = femwaist, y = femweight)
plt.xlabel('Cintura Fem')
plt.ylabel('Peso Fem')
plt.title('Cintura x Peso Mujeres')

plt.show()

plt.figure(figsize = (6,6))
plt.scatter(x = menwaist, y = menweight)
plt.xlabel('Cintura Men')
plt.ylabel('Peso Men')
plt.title('Cintura x Peso Hombres')

plt.show()
